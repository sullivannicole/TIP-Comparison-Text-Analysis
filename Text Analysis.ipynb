# %% [markdown]
# Text analysis module difflib comes with Python 3.
# If you don't already have pandas, install by running either "pip install pandas" or "conda install pandas" (if you're installing with Anaconda) in the command line.  See [here](https://docs.python.org/3/installing/index.html) for more info.

# %%
from difflib import SequenceMatcher
import difflib
import pandas as pd
import numpy as np

# %%
# Display all outputs from a chunk, not just last ouptut
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Import cleaned text descriptions
proj_descs = pd.read_csv("Text descriptions differ.csv")

# %%
# Create variable with match ratio of two strings

match_ratio = [] # empty list

for i in range(len(proj_descs)):
    # Fill empty list with dictionary containing Project ID and match ratio between two descriptions
    match_ratio.append({SequenceMatcher(None, proj_descs['Draft_desc'][i], proj_descs['Final_desc'][i]).ratio(), proj_descs['Projnum'][i]})
    
    # Convert dictionary to dataframe, with columns "Match_ratio" and "Projnum"
    ratio_df = pd.DataFrame(match_ratio,
                           columns = ['Match_ratio',
                                     'Projnum'])

# %%
# Check outputs
ratio_df
# Out:
#     Match_ratio      Projnum
# 0      0.970874  880M-CA-20A
# 1      0.970874  880M-CA-21A
# 2      0.970874  880M-CA-22A
# 3      0.660714  071-070-040
# 4      0.889908  086-619-034
# 5      0.855615     7102-135
# 6      0.805970     2710-47B
# 7      0.960000  002-614-044
# 8      0.970190  027-681-035
# 9      0.980392      2750-89
# 10     0.954296      1012-24
# 11     0.939394  090-080-017
# 12     0.990476  010-090-008
# 13     0.988506     2782-330
# 14     0.992233     6284-180
# 15     0.569588      8286-81
# 16     0.812261     2781-498
# 17     0.937888     6282-212
# 18     0.718121     8282-128
# 19     0.993377     1901-184
# 20     0.874172     6216-136
# 21     0.668293      1925-56
# 22     0.912621      1380-86
# 23     0.981413     2714-144
# 24     0.912281     2714-145
# 25     0.886076  163-291-008
# 26     0.875000  107-090-010
# 27     0.970874     1985-148
# 28     0.972477     1985-150
# 29     0.960526     6282-236
# 30     0.825607      7002-48
# 31     0.864865     2732-105
# 32     0.924925     8209-111
# 33     0.846154   880M-TE-20
# 34     0.974747  141-030-047
# 35     0.831683  110-129-006
# 36     0.956522     6282-190
# 37     0.984615      1926-22
# 38     0.963504      1008-86
# 39     0.969325      0215-77
# 40     0.738806     2713-123
# 41     0.989071      1928-71
# 42     0.985251     1982-203
# 43     0.980263  070-596-015
# 44     0.979695     2785-408
# 45     0.966443     6285-160
# 46     0.985294     0207-110
# 47     0.805970     2710-47B
# 48     0.989305      2758-77

# %% [markdown]
# Using a similar method to 'mutate' is preferable, since we want the original dataframe with the additional variable.  Do this with lambda.

# %%
proj_descs['match_ratio'] = proj_descs.apply(lambda proj_descs:
                                             SequenceMatcher(None,
                                                             proj_descs['Draft_desc'],
                                                             proj_descs['Final_desc']).ratio(), axis = 1)

# %%
proj_descs.head(10)
# Out:
#        Projnum                                         Draft_desc  \
# 0  880M-CA-20A   17new districtwide setaside project delivery ...
# 1  880M-CA-21A   17new districtwide setaside project delivery ...
# 2  880M-CA-22A   17new districtwide setaside project delivery ...
# 3  071-070-040  sherburne csah 13, construct roundabout at cr ...
# 4  086-619-034  wright county csah 19, from lamplight dr to n ...
# 5     7102-135  us 10, from xenia ave st to norfolk ave in elk...
# 6     2710-47B   cocii mn65, at bridge #2440 (3rd ave s) over ...
# 7  002-614-044   ac csah 14, 0.15 mi e of csah 18, bridge 0201...
# 8  027-681-035  csah 81, 0.04 mile n of 71st ave (csah 8) to 0...
# 9      2750-89   ada us169, at hennepin csah 130 (77th ave n/e...
#
#                                           Final_desc  Draft_total  \
# 0   17new districtwide setaside project delivery ...      5800000
# 1   17new districtwide setaside project delivery ...      3050000
# 2   17new districtwide setaside project delivery ...      3150000
# 3   ac sherburne csah 13, construct roundabout at...      1000000
# 4   ac wright county csah 19, from lamplight dr t...      5000000
# 5  us 10, from xenia ave st to norfolk ave in elk...      8750000
# 6   cmgc mn65, at bridge #2440 (3rd ave s) over m...       701552
# 7   ac csah 14, 0.15 mi e of csah 18, bridge 0201...       800000
# 8  csah 81, 0.04 mile n of 71st ave (csah 8) to 0...     20421000
# 9  us169, at hennepin csah 130 (77th ave n/elm cr...       977000
#
#    Final_total  match_ratio
# 0      5800000     0.970874
# 1      3050000     0.970874
# 2      3150000     0.970874
# 3      2250000     0.660714
# 4      5000000     0.889908
# 5      8750000     0.855615
# 6     32100000     0.805970
# 7      1500000     0.960000
# 8     20421000     0.970190
# 9       977000     0.980392

# %% [markdown]
# Is it possible to simply look at the differences between the two strings?

# %%
for line in enumerate(difflib.ndiff(proj_descs['Draft_desc'], proj_descs['Final_desc'])):
    print (line)
# Out:
# -  17new districtwide setaside project delivery fy20
# +  17new districtwide setaside project delivery fy 2020
# ?                                                 +  ++
#
# -  17new districtwide setaside project delivery fy21
# +  17new districtwide setaside project delivery fy 2021
# ?                                                 +++
#
# -  17new districtwide setaside project delivery fy22
# +  17new districtwide setaside project delivery fy 2022
# ?                                                 +++
#
# - sherburne csah 13, construct roundabout at cr 40 intersection in elk river
# +  ac sherburne csah 13, construct roundabout at sherburne cr 40 intersection and construct roundabout at sherburne co csah 33 intersection in elk river
# - wright county csah 19, from lamplight dr to n of 70th st in albertville, extend multilane roadway
# +  ac wright county csah 19, from lamplight dr to n of 70th st in albertville, extend multilane roadway(ac payback in 2020)
# ? ++++                                                                                                 ++++++++++++++++++++
#
# - us 10, from xenia ave st to norfolk ave in elk river (ebl & wbl), reconstruction
# + us 10, from xenia ave st to norfolk ave in elk river (ebl & wbl), reconstruction (including bike/ped trail)
# ?                                                                                 +++++++++++++++++++++++++++
#
# +  cmgc mn65, at bridge #2440 (3rd ave s) over mississippi river in mpls rehab bridge 2440
# +  ac csah 14, 0.15 mi e of csah 18, bridge 02015 over coon creek in coon rapids rehab pier caps, replace deck panels (ac project, payback in fy20)
# + csah 81, 0.04 mile n of 71st ave (csah 8) to 0.1 mile n of 85th ave in brooklyn park reconstruct from four lane divided rural roadway to six lane divided urban roadway, multi use trail
# + us169, at hennepin csah 130 (77th ave n/elm creek blvd n) in brooklyn park/maple grove signal and lighting system replacement
# +  spp us212, from 0.10 mi w of the w jct mn 5/cr 131 to 0.10 mi w of csah 36 bituminous mill and overlay, cold in place recycling, pavement reconstruction, signal replacements, reduced conflict intersections at morse st and csah 34, ada improvements and drainage in norwood young america
# + apple valley transit station modernization. expand capacity by 330 spaces at cedar ave and garret ave
# + along mn 5 from minnewashta pkwy in victoria to century blvd in chanhassen construct mn 5 regional trail
# +  spp ada i35w, from portland ave to washington ave in mpls bituminous mill and overlay, concrete pavement rehabilitation, repair drainage structures and pipe, ada upgrades, tms
# +  ac podi spp 17new chap3 chap117 ada i35w, from co rd b2 in roseville to 0.1 mi n sunset ave (anoka cr 53) in lino lakes, construct mnpass lane from cr c to lexington ave (anoka csah 17), conc ovly from cr c to cr 53, misc pavement reconstruct & bit m&o, rehab 17 bridges and replace 5 bridges, add auxiliary lanes at multiple locations, noise walls and on us10, from n jct i35w to 0.7 mi e csah j, construct wb auxiliary lane, eb conc ovly, noise wall (associated to 6243 18) (ac project, paybacks in fy20, fy21, fy22)
# +  spp i694 in oakdale 10th st (csah10) to jct i694/i494/i94 and i494, 0.1 mi s tamarack rd to jct i694/i494/i94 – concrete overlay; auxiliary lane sb from 10th st to i94 and i94 to tamarack rd; replace and widen bridges 82831 and 82832; rehab bridge 82817 and install center pier strut, reconstruct all loops at i94 interchange and widen se ramp, overlay ramps and loops at tamarack rd and overlay se and sw ramps at 10th st interchange
# +  17new chap3 i94 bridges 27909 eb and 27925 wb and i694 bridge 27926 eb at jct shingle creek in brooklyn center install pier pile wraps for three piers
# +  spp 17new ada i94, from mn280 to 0.1 mi w of western ave in st paul bituminous mill and overlay, erosion control, drainage repair, signal replacement and ada improvements
# + adjacent to i94 from manning ave to midwest trail n in afton reconstruct bituminous bike trail and drainage
# +  17new chap3 mn13 at mn77 in eagan replace high mast tower lighting systems
# +  ada mn51, at hoyt ave in falcon hgts/st paul signal system replacement, ada upgrades
# +  ada mn77, at dakota csah 32 (cliff rd) over mn77 and at dakota cr30 (diffley rd) in eagan rehab bridge 19067, ada improvements, guardrail, lighting replacement, concrete pavement rehab, signal replacement at mn77/cliff rd, lighting replacement at mn77/diffley rd
# + us10 at dayton port rest area in ramsey and i35 at chisago csah1 in rush city replace lighting (tied to 1380 84)
# +  ada us12, at carlson pkwy north ramp (deer creek pkwy) and south ramp (oakland rd) in minnetonka signal replacement and ada improvements
# +  spp ada us12, at central ave (csah 101) in wayzata rehabilitation on bridge #27133 and approach panels, concrete pavement rehab, signals, lighting and ada
# + msas 291 (beltline blvd) from w 36th st to minnetonka blvd & csah 25 from beltline blvd to lynn ave and lynn ave from csah 25 to minnetonka blvd in st louis park construct pedestrian facilities and streetscaping elements
# + e bloomington freeway from w 106th st to w 99th st in bloomington construct sidewalk and reconstruct roadway
# +  ella spp 17new i494, from 3rd ave s in s st paul to e end of mn river bridge in eagan mill and overlay, drainage,
# rehab 7 bridges, guardrail, tms, turn lanes, signals, ada, and sidewalk (tied to 1985 150)
# +  ella i494, from e of concord st in s st paul to mn52 in inver grove heights replace lighting (tied to 1985 148)
# +  17new i94 wb from pierce st to fairview ave in st paul fence replacement
# +  17new chap3 th 21, from n end bridge 9124 to mill st in jordan replace bridge 9123 over up railroad, reconstruct pavement, build retaining walls, repair erosion, construct drainage structures and storm sewer pipe
# +  spp chap3 mn5, jct i494 in hennepin co to s end of the mississippi river bridge concrete overlay, concrete pavement rehab, grading, paving, cable median barrier,  rehab of 11 bridges
# +  17new ada mn95, from 0.2 mi north of 8th ave n in bayport to 0.1 mi south of i94 in lakeland bituminous mill and overlay, cold in place recycling, ada ped ramp upgrades, drainage
# + districtwide setaside for roadside safety ($4.2m) projects fy 2020
# + msas 313 (hennepin ave) from msas 186 (spruce place) to msas 375 (13th st) and on msas 179 (harmon place) from msas 223 (10th st) to msas 225 (12th st) in mpls install mast arms on five traffic signals
# +  ac 101st ave n at us 169 in brooklyn park construct interchange (associated to 2750 92) (ac project, payback in fy21)
# +  17new chap3 eb i94, from prior ave to fairview ave in st paul noisewall
# +  spp mn316, from jct us61 in goodhue county to jct us61 in dakota county bituminous mill and overlay, pedestrian trail and signs
# + mn41, at 82nd st in chaska signal replacement and ada improvements
# + us10, n and s ramps at round lake blvd in coon rapids signal system replacement
# + us12, from hennepin csah 6 in orono to hennepin csah 29 in maple plain construct concrete median barrier, reconstruct pavement
# +  spp us52, from 0.1 mi n of the us52/i494 interchange in inver grove hts to plato ave in st paul mill and overlay, cpr, weight enforcement pull off pad, wim sensors, ada and signing
# +  lga i35e, from lone oak rd (csah 26) to pilot knob (csah 31) in eagan signal replacements at lone oak, pilot knob and yankee doodle, free right modifications at pilot knob
# +  sppf mn071 mn13 and dakota ave in savage, from w of dakota ave to e of yosemite grade separated interchange at dakota ave, frontage roads and access ramps
# +  chap214 i494, at hennepin csah 9 (rockford road) in plymouth re deck bridge #27972, repair approaches including bituminous mill and concrete pavement, signals, drainage, ada, add turn lanes on ramps
# + i694 and silver lake rd n and s ramps in new brighton signal replacement
# +  spp ada mn65, from bridge under csah 10 in spring lake park to 153rd ave in ham lake mill and overlay, drainage repairs, ada improvements
#    cocii mn65, at bridge #2440 (3rd ave s) over mississippi river in mpls design of major structure rehab of bridge
# -  ac csah 14, 0.15 mi e of csah 18, bridge 02015 over coon creek in coon rapdis rehab pier caps, replace deck panels (ac project, paybacks in fy19 and fy20)
# - csah 81, 0.04 mile n of 71st ave (csah 8) to 0.04 mile s of 83rd ave in brooklyn park reconstruct from four lane divided rural roadway to six lane divided urban roadway, multi use trail
# -  ada us169, at hennepin csah 130 (77th ave n/elm creek blvd n) in brooklyn park/maple grove signal and lighting system replacement
# -  spp us212, from 0.10 mi w of the w jct mn 5/cr 131 to 0.10 mi w of csah 36 bituminous mill and overlay, pavement reconstruction, signal replacements, reduced conflict intersections at morse st and csah 34, ada improvements and drainage in norwood young america
# - apple valley transit station expansion. expand capacity by 330 spaces at cedar ave and garret ave
# - along mn 5 from minnewashta pkwy in victoria to century blvd in chanhassen reconstruct mn 5 regional trail
# -  spp i35w, from portland ave to washington ave in mpls bituminous mill and overlay, concrete pavement rehabilitation, repair drainage structures and pipe, ada upgrades, tms
# -  ac podi spp 17new chap3 ada i35w, from co rd b2 in roseville to 0.1 mi n sunset ave (anoka cr 53) in lino lakes, construct mnpass lane from cr c to lexington ave (anoka csah 17), conc ovly from cr c to cr 53, misc pavement reconstruct & bit m&o, rehab 17 bridges and replace 5 bridges, add auxiliary lanes at multiple locations, noise walls and on us10, from n jct i35w to 0.7 mi e csah j, construct wb auxiliary lane, eb conc ovly, noise wall (associated to 6243 18) (ac project, paybacks in fy20, fy21, fy22)
# -  spp i694 in oakdale 10th st (csah10) to jct i694/i494/i94 and i494, 0.1 mi s tamarack rd to jct i694/i494/i94 – concrete overlay; auxiliary lane sb from 10th st to i94; replace and widen bridges 82831 and 82832; reconstruct sw loop; i94 from jct i694/i494/i94 to 0.8 mi w radio dr remove concrete median to modify collector distributor ramp
# -  17new chap3 i94 bridges 27909 eb and 27925 wb at jct shingle creek pkwy install pier pile wraps for two piers
# -  spp 17new ada i94, from mn280 to 0.1 mi w of western ave in st paul bituminous mill and overlay, erosion control, drainage repair and ada improvements
# - adjacent to i94 from manning ave to midwest trail n in afton and from 0.8 mi e of neal ave n to 0.3 mi w of stagecoach trail n in w lakeland twp reconstruct bituminous bike trail and drainage
# -  17new chap 3 mn13 at mn77 in eagan replace high mast tower lighting systems
# - mn51, at hoyt ave in falcon hgts/st paul signal system replacement
# -  ada mn77, at dakota csah 32 (cliff rd) over mn77 and at dakota cr30 (diffley rd) in eagan rehab bridge 19067, ada improvements, guardrai, lighting
# - us10 at dayton port rest area in ramsey and i35 at chisago csah1 in rush city replace lighting
# - us12, at carlson pkwy north ramp (deer creek pkwy) and south ramp (oakland rd) in minnetonka signal replacement and ada improvements
# -  spp ada us12, at central ave (csah 101) in wayzata rehabilitation on bridge #27133 and approach panels, signals, lighting and ada
# - msas 291 (beltline blvd) from w 36th st to minnetonka blvd & csah 25 from beltline blvd to lynn ave in st louis park construct pedestrian facilities and streetscaping elements
# - e bloomington freeway from w 106th st to w 99th st in bloomington construct sidewalk
# -  flex19 spp 17new i494, from 3rd ave s in s st paul to e end of mn river bridge in eagan mill and overlay, drainage,
# rehab 6 bridges, guardrail, tms, turn lanes, signals, ada, and sidewalk (tied to 1985 150)
# - i494, from e of concord st in s st paul to mn52 in inver grove heights replace lighting (tied to 1985 148)
# -  17new chap3 i94 wb from pierce st to fairview ave in st paul fence replacement
# -  17new chap3 th 21, from helena st to the northern intersection with helena blvd in jordan replace bridge 9123 over up railroad, reconstruct pavement, build retaining walls, repair erosion, construct drainage structures and storm sewer pipe
# -  spp mn5, jct i494 in hennepin co to s end of the minnesota river bridge concrete overlay, grading, paving, cable median barrier,  rehab of 11 bridges
# -  17new ada mn95, from 0.2 mi north of 8th ave n in bayport to 0.1 mi south of i94 in lakeland bituminous mill and overlay, ada ped ramp upgrades, drainage
# - districtwide setaside for water resources ($64k), roadside safety ($4.2m) projects fy 2020
# - msas 25 (hennepin ave) from msas 86 (spruce place) to msas 75 (13th st) and on msas 79 (harmon place) from msas 23 (10th st) to msas 25 (12th st) in mpls install mast arms on five traffic signals
# - 101st ave n at us 169 in brooklyn park construct interchange (associated to 2750 92)
# -  chap3 eb i94, from prior ave to fairview ave in st paul noisewall
# -  spp ada mn316, from jct us61 in goodhue county to jct us61 in dakota county bituminous mill and overlay, pedestrian trail and signs
# -  ada mn41, at 82nd st in chaska signal replacement and ada improvements
# -  ada us10, n and s ramps at round lake blvd in coon rapids signal system replacement
# - us12, from hennepin csah 6 in orono to intersection with hennepin csah 29 in maple plain widen to construct 10 foot buffer with median barrier
# -  spp ada us52, from 0.1 mi n of the us52/i494 interchange in inver grove hts to plato ave in st paul mill and overlay, cpr, weight enforcement pull off pad, wim sensors, ada and signing
# - i35e, from lone oak rd (csah 26) to pilot knob (csah 31) in eagan signal replacements at lone oak, pilot knob and yankee doodle, free right modifications at pilot knob
# -  sppf mn13 and dakota ave in savage, from w of dakota ave to e of yosemite grade separated interchange at dakota ave, frontage roads and access ramps
# -  spp i494, at hennepin csah 9 (rockford road) in plymouth re deck bridge #27972, repair approaches including bituminous mill and concrete pavement, signals, drainage, ada, add turn lanes on ramps
# -  ada i694 and silver lake rd n and s ramps in new brighton signal replacement
# -  spp mn65, from bridge under csah 10 in spring lake park to 153rd ave in ham lake mill and overlay, drainage repairs, ada improvements
# -  cmgc mn65, at bridge #2440 (3rd ave s) over mississippi river in mpls rehab bridge 2440
# -  spp mn77, from 0.5 mi s of old shakopee road in bloomington to mn62 in minneapolis bituminous mill and overlay and extend right turn lane on exit ramp from nb mn77 to old shakopee road
# +  spp ada mn77, from 0.5 mi s of old shakopee road in bloomington to mn62 in minneapolis bituminous mill and overlay and extend right turn lane on exit ramp from nb mn77 to old shakopee road
# ?     ++++

# %% [markdown]
# There are quite a few strings where a couple additions at the beginning of the string shift the entire statement downward, making everything look like an addition.  Instead, collect blocks where text is the same, and then remove these blocks from the original strings to obtain the difference between the two.

# %%
output_list = [li for li in difflib.ndiff(proj_descs['Draft_desc'][3], proj_descs['Final_desc'][3]) if li[0] != ' ']
words = [w.replace(' ', '').replace('+', '') for w in output_list]
#words
merged_list = [''.join(words)]
merged_list

#str_no_plus = merged_list[0].replace('+', '')
#str_no_plus.replace(' ', '')
# Out:
# ['acsherburneintersectionandconstructroundaboutatsherburnecocsah33']

# %%
string1 = proj_descs['Draft_desc'][8]
string2 = proj_descs['Final_desc'][8]
projnum = proj_descs['Projnum'][8]

matches = difflib.SequenceMatcher(
    None, string1, string2).get_matching_blocks()

match_lista = []
match_listb = []
for match in matches:
    match_lista.append(string1[match.a:match.a+match.size])
    match_listb.append(string2[match.b:match.b+match.size])

i = 0
while i <len(match_lista):
    string1 = string1.replace(match_lista[i], '')
    string2 = string2.replace(match_listb[i], '')
    i += 1
    
strings = pd.DataFrame({'Final_draft': [string1],
                        'Draft_final': [string2],
                        'Projnum': [projnum]})
strings
# Out:
#   Draft_final Final_draft      Projnum
# 0       1n5th      04s3rd  027-681-035

# %%
match_lista
# Out:
# ['csah 81, 0.04 mile n of 71st ave (csah 8) to 0.',
#  ' mile ',
#  ' of 8',
#  ' ave in brooklyn park reconstruct from four lane divided rural roadway to six lane divided urban roadway, multi use trail',
#  '']

# %% [markdown]
# That's great!  We got all the code to work for a single row.  Now let's create a function so we can iterate over all the rows in the input df.

# %%
# Create a function that can be iterated with
def find_difference(x):
    string1 = proj_descs['Draft_desc'][x]
    string2 = proj_descs['Final_desc'][x]
    projnum = proj_descs['Projnum'][x]

    matches = difflib.SequenceMatcher(
        None, string1, string2).get_matching_blocks()

    match_lista = []
    match_listb = []
    for match in matches:
        match_lista.append(string1[match.a:match.a+match.size])
        match_listb.append(string2[match.b:match.b+match.size])
    
    i = 0
    while i <len(match_lista):
        string1 = string1.replace(match_lista[i], '')
        string2 = string2.replace(match_listb[i], '')
        i += 1
    
    strings = pd.DataFrame({'Deletion_from_draft': [string1],
                        'Addition_in_final': [string2],
                        'Projnum': [projnum]})
    return(strings)

# %%
diff_21 = find_difference(21)

# %%
differences = []

for i in range(len(proj_descs)):
    differences.append(find_difference(i))

# %%
diff_df = pd.concat(differences)

# %%
diff_df
# Out:
#                                    Addition_in_final  \
# 0
# 0                                                 20
# 0                                                 20
# 0   ac sherburne  intersection and construct roun...
# 0                            ac (ac payback in 2020)
# 0                         (including bike/ped trail)
# 0                                            mg 2440
# 0  is rehab pier caps, replace eck panels (ac pro...
# 0                                              1n5th
# 0
# 0                          cold in place recycling,
# 0  modrniztion. xpnd cpcity by 330 spcs t cdr v n...
# 0
# 0                                                ada
# 0                                            chap117
# 0   and i94 to tamarack rdhab bridge 82817 and in...
# 0      nd i694 bridge 27926 eb ain brooln centerhree
# 0                               , signal replacement
# 0
# 0
# 0                                 ada , ada upgrades
# 0  l, lighting replacement, concrete pavement reh...
# 0                                  (tied to 1380 84)
# 0                                               ada
# 0                          concrete pavement rehab,
# 0      and lynn ave from csah 25 to minnetonka blvd
# 0                            and reconstruct roadway
# 0  ellaspp17newi494,from3rdavesinsstpaultoeendofm...
# 0                                              ella
# 0
# 0  n endridge 9124 to mill st in jordan replaceri...
# 0   chap3iippi, concrete pavement rehab, grading,...
# 0                          cold in place recycling,
# 0
# 0  313 (hennepin ave) from 186 (spruce place) to ...
# 0                  ac  (ac project, payback in fy21)
# 0                                              17new
# 0
# 0
# 0
# 0                          cncr mdian barrir, rpavmn
# 0
# 0                                               lga
# 0                                              mn071
# 0  cha214i494,athenneincsah9(rockfordroad)inlymou...
# 0
# 0                                                ada
# 0                    oiidesign of major struture  of
# 0                                                ada
#
#                                  Deletion_from_draft      Projnum
# 0                                                     880M-CA-20A
# 0                                                     880M-CA-21A
# 0                                                     880M-CA-22A
# 0                                                     071-070-040
# 0                                                     086-619-034
# 0                                                        7102-135
# 0                    oiidesign of major struture  of     2710-47B
# 0  is rehab pier caps, replace eck panels (ac pro...  002-614-044
# 0                                             04s3rd  027-681-035
# 0                                               ada       2750-89
# 0                                                         1012-24
# 0  xpnsion. xpnd cpcity by 330 spcs t cdr v nd gr...  090-080-017
# 0                                                 re  010-090-008
# 0                                                        2782-330
# 0                                                        6284-180
# 0  conct s loop; i94 from jct i694/i494/i94 to .8...      8286-81
# 0                                               pwwo     2781-498
# 0                                                        6282-212
# 0  and from 0.8 mi e of neal ave n to 0.3 mi w of...     8282-128
# 0                                                        1901-184
# 0                                                        6216-136
# 0                                         , lighting      1925-56
# 0                                                         1380-86
# 0                                                        2714-144
# 0                                                        2714-145
# 0                                                     163-291-008
# 0                                                     107-090-010
# 0  flex19spp17newi494,from3rdavesinsstpaultoeendo...     1985-148
# 0                                                        1985-150
# 0                                              chap3     6282-236
# 0  helena st to the northern intersection with he...      7002-48
# 0  nneota, grading, paving, cable median barrier,...     2732-105
# 0                                                        8209-111
# 0                            water resources ($64k),   880M-TE-20
# 0  25 (hennepin ave) from 86 (spruce place) to 75...  141-030-047
# 0                                                     110-129-006
# 0                                                        6282-190
# 0                                                ada      1926-22
# 0                                               ada       1008-86
# 0                                               ada       0215-77
# 0      inrscin wih widn  10 f buffr wih mdian barrir     2713-123
# 0                                                ada      1928-71
# 0                                                        1982-203
# 0                                                     070-596-015
# 0  si494,athenneincsah9(rockfordroad)inlymouthred...     2785-408
# 0                                               ada      6285-160
# 0                                                        0207-110
# 0                                            mg 2440     2710-47B
# 0                                                         2758-77

# %%
proj_comparisons = pd.merge(proj_descs, diff_df, on = 'Projnum')

# %%
pd.DataFrame.to_csv(proj_comparisons, "Differing Descriptions Comparison.csv")
